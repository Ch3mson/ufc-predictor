# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('ufc-master.csv')

# %%
data.head()
# Out:
#         RedFighter        BlueFighter  RedOdds  BlueOdds  RedExpectedValue  \
# 0  Jack Hermansson          Joe Pyfer    205.0    -250.0          205.0000
# 1          Dan Ige         Andre Fili   -185.0     154.0           54.0541
# 2   Robert Bryczek      Ihor Potieria   -230.0     190.0           43.4783
# 3     Brad Tavares  Gregory Rodrigues    190.0    -230.0          190.0000
# 4  Michael Johnson    Darrius Flowers   -155.0     130.0           64.5161
#
#    BlueExpectedValue        Date                Location Country Winner  ...  \
# 0            40.0000  2024-02-10  Las Vegas, Nevada, USA     USA    Red  ...
# 1           154.0000  2024-02-10  Las Vegas, Nevada, USA     USA    Red  ...
# 2           190.0000  2024-02-10  Las Vegas, Nevada, USA     USA   Blue  ...
# 3            43.4783  2024-02-10  Las Vegas, Nevada, USA     USA   Blue  ...
# 4           130.0000  2024-02-10  Las Vegas, Nevada, USA     USA    Red  ...
#
# ...
